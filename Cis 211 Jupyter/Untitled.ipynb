# %%
words = [w.strip() for w in open('wordlist.txt')]

# %%
words
# Out:
# ["I'd",
#  "I'll",
#  "I'm",
#  "I've",
#  'a',
#  'aalii',
#  'aardvark',
#  'aardwolf',
#  'aardwolves',
#  'aas',
#  'aba',
#  'abac',
#  'abaca',
#  'abacist',
#  'aback',
#  'abactinal',
#  'abacus',
#  'abaft',
#  'abalone',
#  'abampere',
#  'abandon',
#  'abandoned',
#  'abandonedly',
#  'abandonee',
#  'abandoner',
#  'abandonment',
#  'abase',
#  'abased',
#  'abasement',
#  'abaser',
#  'abash',
#  'abashed',
#  'abashedly',
#  'abashment',
#  'abasia',
#  'abasing',
#  'abatable',
#  'abate',
#  'abated',
#  'abatement',
#  'abater',
#  'abating',
#  'abatis',
#  'abatjour',
#  'abatjours',
#  'abator',
#  'abattis',
#  'abattoir',
#  'abaxial',
#  'abaxile',
#  'abb',
#  'abba',
#  'abbacies',
#  'abbacy',
#  'abbatial',
#  'abbess',
#  'abbey',
#  'abbeys',
#  'abbot',
#  'abbotcy',
#  'abbotship',
#  'abbreviate',
#  'abbreviated',
#  'abbreviating',
#  'abbreviation',
#  'abbreviator',
#  'abcoulomb',
#  'abdicable',
#  'abdicant',
#  'abdicate',
#  'abdicated',
# ...

# %%
sum( [len(w) for w in words])/len(words)
# Out:
# 8.972176866918154
